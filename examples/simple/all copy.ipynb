# %%
import os
import shutil
shutil.rmtree('./configurations')

# %%
import set_configs
set_configs.create_config()
# Out:
# ---  new folder ./configurations/N2  ---
# ---  new folder ./configurations/N3  ---
# ---  new folder ./configurations/N4  ---
# ---  new folder ./configurations/N5  ---
# ---  new folder ./configurations/N6  ---
# ---  new folder ./configurations/N7  ---
# ---  new folder ./configurations/N8  ---
# ---  new folder ./configurations/N9  ---
# ---  new folder ./configurations/N10  ---
# ---  new folder ./configurations/N11  ---
# ---  new folder ./configurations/N12  ---
# ---  new folder ./configurations/N13  ---
# ---  new folder ./configurations/N14  ---
# ---  new folder ./configurations/N15  ---
# ---  new folder ./configurations/N16  ---
# ---  new folder ./configurations/N17  ---
# ---  new folder ./configurations/N18  ---
# ---  new folder ./configurations/N19  ---
# ---  new folder ./configurations/N20  ---

# %%
import compute_phonon
compute_phonon.compute_phonon()
# Out:
# --- N = 12 finished ---
# --- N = 15 finished ---
# --- N = 14 finished ---
# --- N = 13 finished ---
# --- N = 7 finished ---
# --- N = 9 finished ---
# --- N = 8 finished ---
# --- N = 6 finished ---
# --- N = 18 finished ---
# --- N = 20 finished ---
# --- N = 16 finished ---
# --- N = 11 finished ---
# --- N = 10 finished ---
# --- N = 17 finished ---
# --- N = 19 finished ---
# --- N = 4 finished ---
# --- N = 3 finished ---
# --- N = 2 finished ---
# --- N = 5 finished ---

# %%
import optimize_pulse
optimize_pulse.optimize_pulse()
# Out:
# ----- N 2 segNum 5 -----
# detuning [-0.03815759911898105, 0.03815759911898105]
# tau 75.0
# mode [[-0.70710678  0.70710678]
#  [ 0.70710678  0.70710678]]
# this ions should have laser shined:  [0 1]
# >>>>>>>>>> P and G calculate time used is: 0.08435487747192383 seconds
# >>>>>>>>>> optimization time used is: 0.10432314872741699 seconds
# segnum 5 (array([-1.11668743, -0.13370942,  1.14783852, -0.13370942, -1.11668743]), array([-1.11668743, -0.13370942,  1.14783852, -0.13370942, -1.11668743]))
# max_amp 1.147838519000087
# ----- N 2 segNum 6 -----
# detuning [-0.03815759911898105, 0.03815759911898105]
# tau 90.0
# mode [[-0.70710678  0.70710678]
#  [ 0.70710678  0.70710678]]
# 2022-04-28 23:16:31.637226: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# this ions should have laser shined:  [0 1]
# >>>>>>>>>> P and G calculate time used is: 0.16151785850524902 seconds
# >>>>>>>>>> optimization time used is: 0.05097794532775879 seconds
# segnum 6 (array([-0.75708825,  0.71572485,  0.7367053 , -0.7367053 , -0.71572485,
#         0.75708825]), array([-0.75708825,  0.71572485,  0.7367053 , -0.7367053 , -0.71572485,
#         0.75708825]))
# max_amp 0.7570882486731604
# ----- break -----
# ----- N 3 segNum 8 -----
# detuning [-0.03407674054392124, 0.03407674054392148, 0.0814536864793105]
# tau 120.0
# mode [[ 4.08248290e-01 -8.16496581e-01  4.08248290e-01]
#  [ 7.07106781e-01  1.19683070e-15 -7.07106781e-01]
#  [-5.77350269e-01 -5.77350269e-01 -5.77350269e-01]]
# this ions should have laser shined:  [0 1]
# >>>>>>>>>> P and G calculate time used is: 0.3838012218475342 seconds
# >>>>>>>>>> optimization time used is: 0.04935121536254883 seconds
# segnum 8 (array([ 0.27993355, -0.97711733,  1.40481042, -0.76852778, -0.51731825,
#         1.32675649, -1.05641963,  0.34812132]), array([ 0.27993355, -0.97711733,  1.40481042, -0.76852778, -0.51731825,
#         1.32675649, -1.05641963,  0.34812132]))
# max_amp 1.4048104200660745
# ----- N 3 segNum 9 -----
# detuning [-0.03407674054392124, 0.03407674054392148, 0.0814536864793105]
# tau 134.99999999999997
# mode [[ 4.08248290e-01 -8.16496581e-01  4.08248290e-01]
#  [ 7.07106781e-01  1.19683070e-15 -7.07106781e-01]
#  [-5.77350269e-01 -5.77350269e-01 -5.77350269e-01]]
# this ions should have laser shined:  [0 1]
# >>>>>>>>>> P and G calculate time used is: 0.4209120273590088 seconds
# >>>>>>>>>> optimization time used is: 0.10376930236816406 seconds
# segnum 9 (array([-0.44911025,  0.98539181, -0.64838563, -0.53229854,  1.10434217,
#        -0.43500939, -0.72820394,  0.95663036, -0.39375274]), array([-0.44911025,  0.98539181, -0.64838563, -0.53229854,  1.10434217,
#        -0.43500939, -0.72820394,  0.95663036, -0.39375274]))
# max_amp 1.1043421727024114
# ----- N 3 segNum 10 -----
# detuning [-0.03407674054392124, 0.03407674054392148, 0.0814536864793105]
# tau 150.0
# mode [[ 4.08248290e-01 -8.16496581e-01  4.08248290e-01]
#  [ 7.07106781e-01  1.19683070e-15 -7.07106781e-01]
#  [-5.77350269e-01 -5.77350269e-01 -5.77350269e-01]]
# this ions should have laser shined:  [0 1]
# >>>>>>>>>> P and G calculate time used is: 0.5651800632476807 seconds
# >>>>>>>>>> optimization time used is: 0.14166784286499023 seconds
# segnum 10 (array([ 0.51828739, -0.77913014,  0.04087181,  0.85884485, -0.46593955,
#        -0.50542869,  0.8514692 ,  0.0851802 , -0.77810956,  0.48030727]), array([ 0.51828739, -0.77913014,  0.04087181,  0.85884485, -0.46593955,
#        -0.50542869,  0.8514692 ,  0.0851802 , -0.77810956,  0.48030727]))
# max_amp 0.8588448451961711
# ----- break -----
# ----- N 4 segNum 10 -----
# detuning [-0.0746640014118608, -0.026766116709028138, 0.02676611670902837, 0.05928403591874801]
# tau 150.0
# mode [[ 0.25490142 -0.65956445  0.65956445 -0.25490142]
#  [ 0.5        -0.5        -0.5         0.5       ]
#  [-0.65956445 -0.25490142  0.25490142  0.65956445]
#  [-0.5        -0.5        -0.5        -0.5       ]]
# this ions should have laser shined:  [1 2]
# >>>>>>>>>> P and G calculate time used is: 0.7970232963562012 seconds
# >>>>>>>>>> optimization time used is: 0.0774068832397461 seconds
# segnum 10 (array([-0.07830986, -0.02198749,  0.54919546, -1.17549191,  0.97763067,
#         0.19161819, -1.29111795,  1.34617355, -0.6906769 ,  0.13720058]), array([-0.07830986, -0.02198749,  0.54919546, -1.17549191,  0.97763067,
#         0.19161819, -1.29111795,  1.34617355, -0.6906769 ,  0.13720058]))
# max_amp 1.3461735540103335
# ----- N 4 segNum 11 -----
# detuning [-0.0746640014118608, -0.026766116709028138, 0.02676611670902837, 0.05928403591874801]
# tau 165.0
# mode [[ 0.25490142 -0.65956445  0.65956445 -0.25490142]
#  [ 0.5        -0.5        -0.5         0.5       ]
#  [-0.65956445 -0.25490142  0.25490142  0.65956445]
#  [-0.5        -0.5        -0.5        -0.5       ]]
# this ions should have laser shined:  [1 2]
# >>>>>>>>>> P and G calculate time used is: 0.784980058670044 seconds
# >>>>>>>>>> optimization time used is: 0.07825112342834473 seconds
# segnum 11 (array([ 0.01684354,  0.25933691, -0.80460854,  0.92261083, -0.01997363,
#        -1.08305441,  1.05108139,  0.0525132 , -0.83945383,  0.69991586,
#        -0.20426011]), array([ 0.01684354,  0.25933691, -0.80460854,  0.92261083, -0.01997363,
#        -1.08305441,  1.05108139,  0.0525132 , -0.83945383,  0.69991586,
#        -0.20426011]))
# max_amp 1.083054406885613
# ----- N 4 segNum 12 -----
# detuning [-0.0746640014118608, -0.026766116709028138, 0.02676611670902837, 0.05928403591874801]
# tau 180.0
# mode [[ 0.25490142 -0.65956445  0.65956445 -0.25490142]
#  [ 0.5        -0.5        -0.5         0.5       ]
#  [-0.65956445 -0.25490142  0.25490142  0.65956445]
#  [-0.5        -0.5        -0.5        -0.5       ]]
# this ions should have laser shined:  [1 2]
# >>>>>>>>>> P and G calculate time used is: 1.2587060928344727 seconds
# >>>>>>>>>> optimization time used is: 0.18227410316467285 seconds
# segnum 12 (array([ 0.21924576, -0.65974468,  0.69430056,  0.12979308, -0.93440271,
#         0.54204938,  0.60020057, -0.88379369,  0.04234868,  0.70595388,
#        -0.6091846 ,  0.18544872]), array([ 0.21924576, -0.65974468,  0.69430056,  0.12979308, -0.93440271,
#         0.54204938,  0.60020057, -0.88379369,  0.04234868,  0.70595388,
#        -0.6091846 ,  0.18544872]))
# max_amp 0.9344027072566711
# ----- break -----
# ----- N 5 segNum 12 -----
# detuning [-0.05578529907685239, -0.021588718120092294, 0.021588718120092526, 0.06406451059950097, 0.08791646455659857]
# tau 180.0
# mode [[-1.72308939e-01  5.02392969e-01 -6.60168061e-01  5.02392969e-01
#   -1.72308939e-01]
#  [ 3.55728185e-01 -6.11111658e-01 -3.96464796e-15  6.11111658e-01
#   -3.55728185e-01]
#  [ 5.19913098e-01 -2.18177232e-01 -6.03471732e-01 -2.18177232e-01
#    5.19913098e-01]
#  [ 6.11111658e-01  3.55728185e-01  4.29387656e-15 -3.55728185e-01
#   -6.11111658e-01]
#  [-4.47213595e-01 -4.47213595e-01 -4.47213595e-01 -4.47213595e-01
#   -4.47213595e-01]]
# this ions should have laser shined:  [1 3]
# >>>>>>>>>> P and G calculate time used is: 1.5946931838989258 seconds
# >>>>>>>>>> optimization time used is: 0.18081188201904297 seconds
# segnum 12 (array([ 0.50419532, -1.60066154,  2.4078721 , -1.39787814, -1.19178899,
#         3.18337868, -2.72856727,  0.57430047,  1.09119084, -1.14516504,
#         0.47970393, -0.0295171 ]), array([ 0.50419532, -1.60066154,  2.4078721 , -1.39787814, -1.19178899,
#         3.18337868, -2.72856727,  0.57430047,  1.09119084, -1.14516504,
#         0.47970393, -0.0295171 ]))
# max_amp 3.1833786844480247
# ----- N 5 segNum 13 -----
# detuning [-0.05578529907685239, -0.021588718120092294, 0.021588718120092526, 0.06406451059950097, 0.08791646455659857]
# tau 194.99999999999997
# mode [[-1.72308939e-01  5.02392969e-01 -6.60168061e-01  5.02392969e-01
#   -1.72308939e-01]
#         0.94701171, -0.46131131]), array([-0.49402268,  0.95790919, -0.38604827, -0.84078243,  0.79655428,
#         0.57353526, -1.06131372, -0.2440164 ,  1.1022364 , -0.20032062,
#        -1.07446209,  0.52008367,  0.82009689, -0.80083288, -0.42163916,
#         0.94701171, -0.46131131]))
# max_amp 1.1022364022932207
# ----- N 5 segNum 18 -----
# detuning [-0.05578529907685239, -0.021588718120092294, 0.021588718120092526, 0.06406451059950097, 0.08791646455659857]
# tau 269.99999999999994
# mode [[-1.72308939e-01  5.02392969e-01 -6.60168061e-01  5.02392969e-01
#   -1.72308939e-01]
#  [ 3.55728185e-01 -6.11111658e-01 -3.96464796e-15  6.11111658e-01
#   -3.55728185e-01]
#  [ 5.19913098e-01 -2.18177232e-01 -6.03471732e-01 -2.18177232e-01
#    5.19913098e-01]
#  [ 6.11111658e-01  3.55728185e-01  4.29387656e-15 -3.55728185e-01
#   -6.11111658e-01]
#  [-4.47213595e-01 -4.47213595e-01 -4.47213595e-01 -4.47213595e-01
#   -4.47213595e-01]]
# this ions should have laser shined:  [1 3]
# >>>>>>>>>> P and G calculate time used is: 2.8591699600219727 seconds
# >>>>>>>>>> optimization time used is: 0.8979940414428711 seconds
# segnum 18 (array([ 0.55232874, -0.79211912, -0.03022651,  0.8814486 , -0.22456118,
#        -0.86418677,  0.45094127,  0.80189802, -0.5615954 , -0.55831201,
#         0.79939649,  0.45098845, -0.85059302, -0.23365617,  0.87529222,
#        -0.02187277, -0.79244317,  0.54275622]), array([ 0.55232874, -0.79211912, -0.03022651,  0.8814486 , -0.22456118,
#        -0.86418677,  0.45094127,  0.80189802, -0.5615954 , -0.55831201,
#         0.79939649,  0.45098845, -0.85059302, -0.23365617,  0.87529222,
#        -0.02187277, -0.79244317,  0.54275622]))
# max_amp 0.8814485970194851
# ----- break -----
# ----- N 6 segNum 14 -----
# detuning [-0.07788970076518809, -0.05256538533855625, -0.018800173813920237, 0.01880017381392047, 0.053197296326655895, 0.07152832786304969]
# tau 210.0
# mode [[-0.12350251  0.38498356 -0.58011618  0.58011618 -0.38498356  0.12350251]
#  [ 0.26231938 -0.57657119  0.31425181  0.31425181 -0.57657119  0.26231938]
#  [-0.40165268  0.44185272  0.37873645 -0.37873645 -0.44185272  0.40165268]
#  [ 0.5143169  -0.0299832  -0.4843337  -0.4843337  -0.0299832   0.5143169 ]
#  [ 0.56870226  0.39566884  0.14150586 -0.14150586 -0.39566884 -0.56870226]
#  [-0.40824829 -0.40824829 -0.40824829 -0.40824829 -0.40824829 -0.40824829]]
# this ions should have laser shined:  [1 4]
# >>>>>>>>>> P and G calculate time used is: 2.0327789783477783 seconds
# >>>>>>>>>> optimization time used is: 0.13100790977478027 seconds
# segnum 14 (array([ 0.33621921, -1.59115565,  3.7399634 , -5.16273916,  3.97093655,
#        -0.5500155 , -2.15038321,  1.92555606,  0.21222409, -1.66050281,
#         1.43405402, -0.5175587 ,  0.00942061,  0.05075267]), array([ 0.33621921, -1.59115565,  3.7399634 , -5.16273916,  3.97093655,
#        -0.5500155 , -2.15038321,  1.92555606,  0.21222409, -1.66050281,
#         1.43405402, -0.5175587 ,  0.00942061,  0.05075267]))
# max_amp 5.162739159166202
]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/all copy.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/all%20copy.ipynb#ch0000003?line=0'>1</a> import optimize_pulse
# ----> <a href='vscode-notebook-cell:/Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/all%20copy.ipynb#ch0000003?line=1'>2</a> optimize_pulse.optimize_pulse()
#
# File ~/Desktop/huawei/alg1_alg2/examples/simple/optimize_pulse.py:57, in optimize_pulse()
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/optimize_pulse.py?line=52'>53</a> #error = p(N,segNum)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/optimize_pulse.py?line=53'>54</a> #in syc_amp MHz = us = 1
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/optimize_pulse.py?line=54'>55</a> syc = syc_amp(ion_number=N_ions,j_list=j_ions,omega=[(x - mu)/MHz for x in Z_freqcal],bij=np.matrix(Z_modes).transpose(),tau=delta_t*segNum/us,segment_num=segNum,lamb_dicke=lamb_dicke,mu = mu/MHz)
# ---> <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/optimize_pulse.py?line=56'>57</a> syc.func2_optimize_process_save_data(plotfig=False, pulse_symmetry = False, ions_same_amps = True)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/optimize_pulse.py?line=59'>60</a> syc.import_amp()
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/examples/simple/optimize_pulse.py?line=60'>61</a> ampList0,ampList1, max_amp = syc.print_amp()
#
# File ~/Desktop/huawei/alg1_alg2/syc_amp/wave_pulse.py:47, in syc_amp.func2_optimize_process_save_data(self, plotfig, pulse_symmetry, ions_same_amps, if_restrict, restrictNum, amp_restrict)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/wave_pulse.py?line=44'>45</a> def func2_optimize_process_save_data(self, plotfig = False, pulse_symmetry = True, ions_same_amps = True,if_restrict = False,restrictNum = None,amp_restrict = 0.5):
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/wave_pulse.py?line=45'>46</a>     #   1. 开始optimization的过程
# ---> <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/wave_pulse.py?line=46'>47</a>     op = AM_optimize(self.detuning_list, self.gate_duration, self.segments_number, self.theta, self.eta, pulse_symmetry = pulse_symmetry, ions_same_amps = ions_same_amps)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/wave_pulse.py?line=47'>48</a>     op._optimizer_AM()
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/wave_pulse.py?line=48'>49</a>     self.P = op.P
#
# File ~/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py:152, in AM_optimize.__init__(self, detuning_list, gate_duration, segments_number, theta, eta, pulse_symmetry, ions_same_amps)
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=149'>150</a> time_start = time.time()
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=150'>151</a> self.P = calculator_P(detuning_list, gate_duration, segments_number)  # define tensor P
# --> <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=151'>152</a> self.G = calculator_G(detuning_list, gate_duration, segments_number, eta)  # define tensor G
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=152'>153</a> self.theta = tf.constant(theta, dtype=tf.dtypes.complex128)  # transfer the target interaction
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=153'>154</a> self.ions_on_index = self.theta_non_zero_index()     #   通过theta的值，看哪些离子上应该打光
#
# File ~/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py:110, in calculator_G(detuning_list, duration, number_of_segments, eta)
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=106'>107</a> def calculator_G(detuning_list, duration, number_of_segments, eta):
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=107'>108</a>     spin_number = len(detuning_list)
# --> <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=109'>110</a>     G_int_terms_real, G_int_terms_imag = pre_process_G_integral(detuning_list, duration, number_of_segments, eta)
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=111'>112</a>     G_real = [[calculator_G_ijspecified_real(G_int_terms_real, detuning_list, duration, number_of_segments, eta, i, j) \
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=112'>113</a>                for i in np.arange(spin_number)] for j in np.arange(spin_number)]
#     <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=113'>114</a>                #for [i,j] in
#
# File ~/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py:50, in pre_process_G_integral(detuning_list, duration, number_of_segments, eta)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=47'>48</a> # print(k)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=48'>49</a> for l in np.arange(k):
# ---> <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=49'>50</a>     _G_mid_real.append([integrate.dblquad(lambda t1, t2: \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=50'>51</a>                            np.cos(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=51'>52</a>                            k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=52'>53</a>                            lambda t1: l * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=53'>54</a>                            lambda t1: (l + 1) * dur_seg)[0] for m in np.arange(len(detuning_list))])
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=54'>55</a>     _G_mid_imag.append([integrate.dblquad(lambda t1, t2: \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=55'>56</a>                            np.sin(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=56'>57</a>                            k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=57'>58</a>                            lambda t1: l * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=58'>59</a>                            lambda t1: (l + 1) * dur_seg)[0] for m in np.arange(len(detuning_list))])
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=59'>60</a> _G_mid_real.append([integrate.dblquad(lambda t1, t2: \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=60'>61</a>                                     np.cos(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=61'>62</a>                                     k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=62'>63</a>                                     lambda t1: k * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=63'>64</a>                                     lambda t1: t1)[0] for m in np.arange(len(detuning_list))])
#
# File ~/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py:50, in <listcomp>(.0)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=47'>48</a> # print(k)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=48'>49</a> for l in np.arange(k):
# ---> <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=49'>50</a>     _G_mid_real.append([integrate.dblquad(lambda t1, t2: \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=50'>51</a>                            np.cos(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=51'>52</a>                            k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=52'>53</a>                            lambda t1: l * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=53'>54</a>                            lambda t1: (l + 1) * dur_seg)[0] for m in np.arange(len(detuning_list))])
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=54'>55</a>     _G_mid_imag.append([integrate.dblquad(lambda t1, t2: \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=55'>56</a>                            np.sin(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=56'>57</a>                            k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=57'>58</a>                            lambda t1: l * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=58'>59</a>                            lambda t1: (l + 1) * dur_seg)[0] for m in np.arange(len(detuning_list))])
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=59'>60</a> _G_mid_real.append([integrate.dblquad(lambda t1, t2: \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=60'>61</a>                                     np.cos(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=61'>62</a>                                     k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=62'>63</a>                                     lambda t1: k * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=63'>64</a>                                     lambda t1: t1)[0] for m in np.arange(len(detuning_list))])
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:601, in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=596'>597</a> def temp_ranges(*args):
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=597'>598</a>     return [gfun(args[0]) if callable(gfun) else gfun,
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=598'>599</a>             hfun(args[0]) if callable(hfun) else hfun]
# --> <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=600'>601</a> return nquad(func, [temp_ranges, [a, b]], args=args,
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=601'>602</a>         opts={"epsabs": epsabs, "epsrel": epsrel})
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:825, in nquad(func, ranges, args, opts, full_output)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=822'>823</a> else:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=823'>824</a>     opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# --> <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=824'>825</a> return _NQuad(func, ranges, opts, full_output).integrate(*args)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:879, in _NQuad.integrate(self, *args, **kwargs)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=876'>877</a> else:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=877'>878</a>     f = partial(self.integrate, depth=depth+1)
# --> <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=878'>879</a> quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=879'>880</a>               **opt)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=880'>881</a> value = quad_r[0]
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=881'>882</a> abserr = quad_r[1]
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=347'>348</a> flip, a, b = b < a, min(a, b), max(a, b)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=349'>350</a> if weight is None:
# --> <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=350'>351</a>     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=351'>352</a>                    points)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=352'>353</a> else:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=353'>354</a>     if points is not None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:463, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=460'>461</a> if points is None:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=461'>462</a>     if infbounds == 0:
# --> <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=462'>463</a>         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=463'>464</a>     else:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=464'>465</a>         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:879, in _NQuad.integrate(self, *args, **kwargs)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=876'>877</a> else:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=877'>878</a>     f = partial(self.integrate, depth=depth+1)
# --> <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=878'>879</a> quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=879'>880</a>               **opt)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=880'>881</a> value = quad_r[0]
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=881'>882</a> abserr = quad_r[1]
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=347'>348</a> flip, a, b = b < a, min(a, b), max(a, b)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=349'>350</a> if weight is None:
# --> <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=350'>351</a>     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=351'>352</a>                    points)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=352'>353</a> else:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=353'>354</a>     if points is not None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:463, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=460'>461</a> if points is None:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=461'>462</a>     if infbounds == 0:
# --> <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=462'>463</a>         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=463'>464</a>     else:
#     <a href='file:///Users/hewenhao/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py?line=464'>465</a>         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# File ~/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py:51, in pre_process_G_integral.<locals>.<lambda>(t1, t2)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=47'>48</a> # print(k)
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=48'>49</a> for l in np.arange(k):
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=49'>50</a>     _G_mid_real.append([integrate.dblquad(lambda t1, t2: \
# ---> <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=50'>51</a>                            np.cos(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=51'>52</a>                            k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=52'>53</a>                            lambda t1: l * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=53'>54</a>                            lambda t1: (l + 1) * dur_seg)[0] for m in np.arange(len(detuning_list))])
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=54'>55</a>     _G_mid_imag.append([integrate.dblquad(lambda t1, t2: \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=55'>56</a>                            np.sin(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=56'>57</a>                            k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=57'>58</a>                            lambda t1: l * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=58'>59</a>                            lambda t1: (l + 1) * dur_seg)[0] for m in np.arange(len(detuning_list))])
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=59'>60</a> _G_mid_real.append([integrate.dblquad(lambda t1, t2: \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=60'>61</a>                                     np.cos(detuning_list[m] * (t1 - t2)),
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=61'>62</a>                                     k * dur_seg, (k + 1) * dur_seg, \
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=62'>63</a>                                     lambda t1: k * dur_seg,
#      <a href='file:///Users/hewenhao/Desktop/huawei/alg1_alg2/syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=63'>64</a>                                     lambda t1: t1)[0] for m in np.arange(len(detuning_list))])
#
# KeyboardInterrupt:

# %%
import simu_heating
simu_heating.num_heating_error()
simu_heating.bound_eq26()
