# %%
import os
import shutil
shutil.rmtree('./configurations')


import set_configs
set_configs.create_config()
# Out:
# ---  new folder ./configurations/N2  ---
# ---  new folder ./configurations/N3  ---
# ---  new folder ./configurations/N4  ---
# ---  new folder ./configurations/N5  ---
# ---  new folder ./configurations/N6  ---
# ---  new folder ./configurations/N7  ---
# ---  new folder ./configurations/N8  ---
# ---  new folder ./configurations/N9  ---
# ---  new folder ./configurations/N10  ---
# ---  new folder ./configurations/N11  ---
# ---  new folder ./configurations/N12  ---

# %%
import compute_phonon
compute_phonon.compute_phonon()
# Out:
# --- N = 11 finished ---
# --- N = 3 finished ---
# --- N = 6 finished ---
# --- N = 9 finished ---
# --- N = 5 finished ---
# --- N = 8 finished ---
# --- N = 12 finished ---
# --- N = 4 finished ---
# --- N = 10 finished ---
# --- N = 7 finished ---
# --- N = 2 finished ---

# %%
import optimize_pulse
optimize_pulse.optimize_pulse()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/all.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a225765696d696e6731227d/gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/all.ipynb#ch0000003vscode-remote?line=0'>1</a> import optimize_pulse
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a225765696d696e6731227d/gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/all.ipynb#ch0000003vscode-remote?line=1'>2</a> optimize_pulse.optimize_pulse()
#
# File ~/alg1_alg2/examples/all_optimizedj1-1/optimize_pulse.py:8, in <module>
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/optimize_pulse.py?line=5'>6</a> sys.path.append('../..')
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/optimize_pulse.py?line=6'>7</a> from my_constants import *
# ----> <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/optimize_pulse.py?line=7'>8</a> from syc_amp.wave_pulse import syc_amp
#      <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/optimize_pulse.py?line=9'>10</a> prefix = './configurations'
#      <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/optimize_pulse.py?line=10'>11</a> all_dir = os.listdir(prefix)
#
# File ~/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/wave_pulse.py:5, in <module>
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/wave_pulse.py?line=1'>2</a> import numpy as np
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/wave_pulse.py?line=2'>3</a> import matplotlib.pyplot as plt
# ----> <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/wave_pulse.py?line=4'>5</a> from .pakages.quantum_dynamics_simulation.AM_optimization import *
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/wave_pulse.py?line=5'>6</a> from .pakages.quantum_dynamics_simulation.segmented_simulation import *
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/wave_pulse.py?line=6'>7</a> from .pakages.quantum_dynamics_simulation.visualization import *
#
# File ~/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py:7, in <module>
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=3'>4</a> import random
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=5'>6</a> import numpy as np
# ----> <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=6'>7</a> import tensorflow as tf
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=7'>8</a> import matplotlib.pyplot as plt
#       <a href='file:///gpfs/share/home/1900011306/alg1_alg2/examples/all_optimizedj1-1/../../syc_amp/pakages/quantum_dynamics_simulation/AM_optimization.py?line=8'>9</a> import scipy.integrate as integrate
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/__init__.py:41, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/__init__.py?line=37'>38</a> import six as _six
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/__init__.py?line=38'>39</a> import sys as _sys
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/__init__.py?line=40'>41</a> from tensorflow.python.tools import module_util as _module_util
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/__init__.py?line=41'>42</a> from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/__init__.py?line=43'>44</a> # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/__init__.py:48, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/__init__.py?line=45'>46</a> from tensorflow.python import data
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/__init__.py?line=46'>47</a> from tensorflow.python import distribute
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/__init__.py?line=47'>48</a> from tensorflow.python import keras
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/__init__.py?line=48'>49</a> from tensorflow.python.feature_column import feature_column_lib as feature_column
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/__init__.py?line=49'>50</a> from tensorflow.python.layers import layers
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py:27, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py?line=23'>24</a> from tensorflow.python import tf2
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py?line=25'>26</a> # See b/110718070#comment18 for more details about this import.
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py?line=26'>27</a> from tensorflow.python.keras import models
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py?line=28'>29</a> from tensorflow.python.keras.engine.input_layer import Input
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py?line=29'>30</a> from tensorflow.python.keras.engine.sequential import Sequential
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/models.py:26, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/models.py?line=23'>24</a> from tensorflow.python.keras import metrics as metrics_module
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/models.py?line=24'>25</a> from tensorflow.python.keras import optimizer_v1
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/models.py?line=25'>26</a> from tensorflow.python.keras.engine import functional
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/models.py?line=26'>27</a> from tensorflow.python.keras.engine import sequential
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/models.py?line=27'>28</a> from tensorflow.python.keras.engine import training
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py:38, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py?line=35'>36</a> from tensorflow.python.keras.engine import keras_tensor
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py?line=36'>37</a> from tensorflow.python.keras.engine import node as node_module
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py?line=37'>38</a> from tensorflow.python.keras.engine import training as training_lib
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py?line=38'>39</a> from tensorflow.python.keras.engine import training_utils
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py?line=39'>40</a> from tensorflow.python.keras.saving.saved_model import network_serialization
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:52, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=49'>50</a> from tensorflow.python.keras.engine import base_layer_utils
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=50'>51</a> from tensorflow.python.keras.engine import compile_utils
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=51'>52</a> from tensorflow.python.keras.engine import data_adapter
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=52'>53</a> from tensorflow.python.keras.engine import training_utils
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=53'>54</a> from tensorflow.python.keras.mixed_precision import loss_scale_optimizer as lso
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py:65, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=62'>63</a>   scipy_sparse = None
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=63'>64</a> try:
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=64'>65</a>   import pandas as pd  # pylint: disable=g-import-not-at-top
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=65'>66</a> except ImportError:
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=66'>67</a>   pd = None
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/__init__.py:22, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/__init__.py?line=18'>19</a> del hard_dependencies, dependency, missing_dependencies
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/__init__.py?line=20'>21</a> # numpy compat
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/__init__.py?line=21'>22</a> from pandas.compat import is_numpy_dev as _is_numpy_dev
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/__init__.py?line=23'>24</a> try:
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/__init__.py?line=24'>25</a>     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py:15, in <module>
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=11'>12</a> import sys
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=13'>14</a> from pandas._typing import F
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=14'>15</a> from pandas.compat.numpy import (
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=15'>16</a>     is_numpy_dev,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=16'>17</a>     np_version_under1p19,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=17'>18</a>     np_version_under1p20,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=18'>19</a> )
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=19'>20</a> from pandas.compat.pyarrow import (
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=20'>21</a>     pa_version_under1p01,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=21'>22</a>     pa_version_under2p0,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=22'>23</a>     pa_version_under3p0,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=23'>24</a>     pa_version_under4p0,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=24'>25</a> )
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/__init__.py?line=26'>27</a> PY39 = sys.version_info >= (3, 9)
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:4, in <module>
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py?line=0'>1</a> """ support numpy compatibility across versions """
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py?line=1'>2</a> import numpy as np
# ----> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py?line=3'>4</a> from pandas.util.version import Version
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py?line=5'>6</a> # numpy versioning
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py?line=6'>7</a> _np_version = np.__version__
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py:1, in <module>
# ----> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=0'>1</a> from pandas.util._decorators import (  # noqa:F401
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=1'>2</a>     Appender,
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=2'>3</a>     Substitution,
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=3'>4</a>     cache_readonly,
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=4'>5</a> )
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=6'>7</a> from pandas.core.util.hashing import (  # noqa:F401
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=7'>8</a>     hash_array,
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=8'>9</a>     hash_pandas_object,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=9'>10</a> )
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/__init__.py?line=12'>13</a> def __getattr__(name):
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py:14, in <module>
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=5'>6</a> from typing import (
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=6'>7</a>     Any,
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=7'>8</a>     Callable,
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=8'>9</a>     Mapping,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=9'>10</a>     cast,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=10'>11</a> )
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=11'>12</a> import warnings
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=13'>14</a> from pandas._libs.properties import cache_readonly  # noqa:F401
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=14'>15</a> from pandas._typing import F
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=17'>18</a> def deprecate(
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=18'>19</a>     name: str,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=19'>20</a>     alternative: Callable[..., Any],
#    (...)
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=24'>25</a>     msg: str | None = None,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/util/_decorators.py?line=25'>26</a> ) -> Callable[[F], F]:
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py:13, in <module>
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=0'>1</a> __all__ = [
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=1'>2</a>     "NaT",
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=2'>3</a>     "NaTType",
#    (...)
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=8'>9</a>     "Interval",
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=9'>10</a> ]
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=12'>13</a> from pandas._libs.interval import Interval
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=13'>14</a> from pandas._libs.tslibs import (
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=14'>15</a>     NaT,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=15'>16</a>     NaTType,
#    (...)
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=20'>21</a>     iNaT,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/__init__.py?line=21'>22</a> )
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/missing.pyx:1, in init pandas._libs.missing()
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py:30, in <module>
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=0'>1</a> __all__ = [
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=1'>2</a>     "dtypes",
#       <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=2'>3</a>     "localize_pydatetime",
#    (...)
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=25'>26</a>     "tz_compare",
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=26'>27</a> ]
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=28'>29</a> from pandas._libs.tslibs import dtypes
# ---> <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=29'>30</a> from pandas._libs.tslibs.conversion import (
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=30'>31</a>     OutOfBoundsTimedelta,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=31'>32</a>     localize_pydatetime,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=32'>33</a> )
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=33'>34</a> from pandas._libs.tslibs.dtypes import Resolution
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=34'>35</a> from pandas._libs.tslibs.nattype import (
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=35'>36</a>     NaT,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=36'>37</a>     NaTType,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=37'>38</a>     iNaT,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=38'>39</a>     nat_strings,
#      <a href='file:///gpfs/share/home/1900011306/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/__init__.py?line=39'>40</a> )
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx:63, in init pandas._libs.tslibs.conversion()
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:1, in init pandas._libs.tslibs.parsing()
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/offsets.pyx:1, in init pandas._libs.tslibs.offsets()
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/timedeltas.pyx:61, in init pandas._libs.tslibs.timedeltas()
#
# File ~/anaconda3/envs/alg1_alg2/lib/python3.8/site-packages/pandas/_libs/tslibs/fields.pyx:22, in init pandas._libs.tslibs.fields()
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:971, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:914, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1407, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1379, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1525, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:156, in _path_isfile(path)
#
# File <frozen importlib._bootstrap_external>:148, in _path_is_mode_type(path, mode)
#
# File <frozen importlib._bootstrap_external>:142, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
import simu_heating
simu_heating.num_heating_error()
simu_heating.bound_eq26()
# Out:
# Jupyter cannot be started. Error attempting to locate jupyter: Select an Interpreter to start Jupyter
#
# Run the following command to install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.
